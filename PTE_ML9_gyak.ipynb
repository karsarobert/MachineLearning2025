# %% [markdown]
# <a href="https://colab.research.google.com/github/karsarobert/MachineLearning2025/blob/main/PTE_ML9_gyak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A mesterséges intelligencia matematikai alapjai gyakorlat
# # PTE Gépi tanulás
#
# ## 9. Gyakorlat: Döntési fák, véletlen erdők, boosting, gridsearch
# ### 2025. november 10.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv("https://raw.githubusercontent.com/karsarobert/MachineLearning2025/main/Movie_classification.csv", header=0) # adatok betöltése

y = df.Start_Tech_Oscar #X,y beállítása
X= df.drop(['Start_Tech_Oscar'], axis = 1)

# %% [markdown]
# #Feladat
# A 8. lecke alapján készítsünk egy Randomforest osztályozót kersztvalidálással a fenti adatkészletre!

# %% [markdown]
# #Feladat
# A 8. lecke alapján készítsünk GridsearchCV hiperparaméter optimalizátort a fenti adatkészlethez! paraméterek: max_depth, min_samples_split, min_samples_leaf, max_features

# %% [markdown]
# Melyek az optimális beállítások?

# %% [markdown]
# Mekkora a pontosság?

# %% [markdown]
# Készítsünk előrejelzést az adatkészlet 12. elemére!

# %% [markdown]
# Vizualizáljuk a döntési fát!

# %% [markdown]
# #Feladat
# Együttes (Ensemble) módszerek segítségével a 8. lecke alapján készítsen modellt!

# %% [markdown]
# #Feladat
# Készítsen a 8. lecke alapján készítsen bagging osztályozót a fenti adatkészlethez!

# %% [markdown]
# #Feladat!
# A 8. lecke alapján készítsen agy AdaBoostClassifier-t a fenti adatkészlethez.

# %% [markdown]
# #Feladat
# A RandomForest Feature importance segítségével határozza meg a feature-ok fontossági sorrendjét!
